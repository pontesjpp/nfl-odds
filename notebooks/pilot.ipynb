# %%
import nflreadpy as nfl

pbp = nfl.load_pbp(2025)
player_stats = nfl.load_player_stats(2025)

# %%
pbp.select([
    "game_id",
    "posteam",
    "defteam",
    "passer_player_name",
    "rusher_player_name",
    "receiver_player_name",
    "passing_yards",
    "rushing_yards",
    "receiving_yards"
])
# Out:
# shape: (48_771, 9)
# ┌────────────┬─────────┬─────────┬────────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ game_id    ┆ posteam ┆ defteam ┆ passer_pla ┆ … ┆ receiver_p ┆ passing_y ┆ rushing_y ┆ receiving │
# │ ---        ┆ ---     ┆ ---     ┆ yer_name   ┆   ┆ layer_name ┆ ards      ┆ ards      ┆ _yards    │
# │ str        ┆ str     ┆ str     ┆ ---        ┆   ┆ ---        ┆ ---       ┆ ---       ┆ ---       │
# │            ┆         ┆         ┆ str        ┆   ┆ str        ┆ f64       ┆ f64       ┆ f64       │
# ╞════════════╪═════════╪═════════╪════════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 2025_01_AR ┆ null    ┆ null    ┆ null       ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ I_NO       ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 2025_01_AR ┆ ARI     ┆ NO      ┆ null       ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ I_NO       ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 2025_01_AR ┆ ARI     ┆ NO      ┆ null       ┆ … ┆ null       ┆ null      ┆ 3.0       ┆ null      │
# │ I_NO       ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 2025_01_AR ┆ ARI     ┆ NO      ┆ K.Murray   ┆ … ┆ T.McBride  ┆ 11.0      ┆ null      ┆ 11.0      │
# │ I_NO       ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 2025_01_AR ┆ ARI     ┆ NO      ┆ K.Murray   ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ I_NO       ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ …          ┆ …       ┆ …       ┆ …          ┆ … ┆ …          ┆ …         ┆ …         ┆ …         │
# │ 2025_22_SE ┆ NE      ┆ SEA     ┆ null       ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ A_NE       ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 2025_22_SE ┆ NE      ┆ SEA     ┆ D.Maye     ┆ … ┆ D.Douglas  ┆ 9.0       ┆ null      ┆ 9.0       │
# │ A_NE       ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 2025_22_SE ┆ NE      ┆ SEA     ┆ D.Maye     ┆ … ┆ K.Boutte   ┆ null      ┆ null      ┆ null      │
# │ A_NE       ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 2025_22_SE ┆ NE      ┆ SEA     ┆ D.Maye     ┆ … ┆ T.Henderso ┆ 24.0      ┆ null      ┆ 24.0      │
# │ A_NE       ┆         ┆         ┆            ┆   ┆ n          ┆           ┆           ┆           │
# │ 2025_22_SE ┆ NE      ┆ SEA     ┆ null       ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ A_NE       ┆         ┆         ┆            ┆   ┆            ┆           ┆           ┆           │
# └────────────┴─────────┴─────────┴────────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %%
pbp_df = pbp.to_pandas()
player_stats_df = player_stats.to_pandas()
